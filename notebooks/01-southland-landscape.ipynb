# %% [markdown]
# # 01 — Southland landscape
#
# **Step 1 (Part A) · Lead: Karl**
#
# Exploratory analysis of the Southland data-centre controversy from the primary-source corpus in `../research/`. Map who is proposing what, who is objecting, and on what specific grounds. Feeds the knowledge graph in `../graph/`.
#
# Every number here traces to a source in `../research/sources/` (see `../docs/methodology.md`).
