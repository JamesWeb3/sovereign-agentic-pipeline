# %% [markdown]
# # 03 — Energy per 1000 tokens
#
# **Step 3 (Part A) · Lead: Karl (with James)**
#
# Analyse the measured watt-hours per 1000 tokens from `../energy/results/`. Compare models and hardware; combine with notebook 02's grid mix to express inference cost in both energy and carbon terms.
#
# Negative results count — an unfavourable number is analysed and published the same as a favourable one (`../docs/methodology.md`).
