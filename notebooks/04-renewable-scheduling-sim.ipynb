# %% [markdown]
# # 04 — Renewable scheduling simulation
#
# **Step 4 (Part A) · Lead: Karl (with James)**
#
# Drive `../scheduling/simulate.py` with the real EMI renewable-share series (notebook 02) and a workload profile (notebook 03). Sweep scheduling policies; quantify the clean-energy gain versus the SLA cost of deferring flexible compute.
#
# This is where the thesis is most falsifiable — if scheduling buys little, that is the finding.
#
# Quick start (from the repo root, with Part A deps installed):
#
# ```python
# from scheduling.simulate import simulate
# result = simulate([0.6, 0.55, 0.5, 0.65, 0.8, 0.9, 0.95, 0.85, 0.7, 0.6], threshold=0.8)
# ```
