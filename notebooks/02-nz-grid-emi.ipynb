# %% [markdown]
# # 02 — NZ grid (EMI)
#
# **Step 2 (Part A) · Lead: Karl (with James)**
#
# Explore NZ's half-hourly generation mix from EMI (see `../grid/`). Renewable share by trading period, seasonal and diurnal patterns — the denominator for every 'clean' claim, and the input series for the scheduling simulation (notebook 04).
#
# Dataset provenance and the licence caveat are in `../grid/README.md` and `../data/README.md`.
